# %% [markdown]
# ## Usao de
# - from qiskit.visualization import plot_state_qsphere
# - from qiskit.visualization import plot_bloch_multivector

# %%
import numpy as np
from qiskit.visualization import plot_state_qsphere

# Definir la magnitud de los componentes del vector de estado
x = np.sqrt(1/2)

# Crear el vector de estado como una lista de números complejos
vec = [x*1, x*1]  # Ambos componentes son reales en este caso

# Imprimir el vector de estado
print("State vector:", vec)

# Graficar el estado en la Q-sphere
plot_state_qsphere(vec)

# %%
from qiskit.visualization import plot_bloch_multivector
import matplotlib.pyplot as plot
plot plot_bloch_multivector(vec)

# %% [markdown]
# from cirq (herramienta de google)

# %% [markdown]
# Represent the state ![image.png](attachment:image.png)
#
# in Qiskit by using both visualization tools mentioned

# %%
import numpy as np
from qiskit.visualization import plot_state_qsphere

# Define the components of the state vector
alpha = (1 + 1j) / 2
beta = (1 - 1j) / 2

# State vector
state_vector = [alpha, beta]

# Print the state vector
print("State vector:", state_vector)

# Plot the state on the Q-sphere
plot_state_qsphere(state_vector)
# Out:
# State vector: [(0.5+0.5j), (0.5-0.5j)]

# %% [markdown]
# # Construct a one-qubit qubit circuit in qiskit
# ## T1 actions:
# - Aply X
# - Aply H
# - Aply Z
# - Aply S
# - Aply I

# %%
import matplotlib
matplotlib.use('TkAgg')  # O cualquier otro backend interactivo que funcione en tu sistema

from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
import matplotlib.pyplot as plt

# Creación de registros
q = QuantumRegister(1, 'q_reg')
c = ClassicalRegister(1, 'c_reg')

# Creación del circuito
qc = QuantumCircuit(q, c)
qc.s(q[0])
qc.measure(q[0], c[0])

# Dibujando el circuito
fig = qc.draw(output='mpl')
plt.show()

# %% [markdown]
# # Aplicando "X" y job.result

# %%
import numpy as np
import matplotlib.pyplot as plt
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, Aer, execute
from qiskit.visualization import plot_bloch_multivector

# Creación de registros
q = QuantumRegister(1, 'q_reg')
c = ClassicalRegister(1, 'c_reg')

# Creación del circuito
qc = QuantumCircuit(q, c)
qc.x(q[0])  # Aplicar la puerta X al qubit q
qc.measure(q[0], c[0])

# Dibujando el circuito
fig = qc.draw(output='mpl')
plt.show()

# Simulador
sim = Aer.get_backend('statevector_simulator')

# Ejecutar el circuito en el simulador
job = execute(qc, sim)

# Obtener el resultado
result = job.result()

# Obtener el estado vectorial del qubit
statevector = result.get_statevector(qc)

# Mostrar el vector de estado
print("State vector:", statevector)

# Visualizar en la esfera de Bloch
plot_bloch_multivector(statevector)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, Aer, execute
#       4 from qiskit.visualization import plot_bloch_multivector
#       6 # Creación de registros
#
# ImportError: cannot import name 'Aer' from 'qiskit' (c:\Users\JEVG\MATLAB Drive\CUANTICA PYTHON\cuantic_jevg\Lib\site-packages\qiskit\__init__.py)
